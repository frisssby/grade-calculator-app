# %% [markdown]
# # Cкрейпинг информации о курсах ФКН ПМИ с портала hse.ru

# %% [markdown]
# Наша задача – собрать данные об оценивании на курсах ОП "Прикладная математика и информатика". Нужную для нас информацию можно найти на странице "Учебные курсы" соответствующей образовательной программы (https://www.hse.ru/ba/ami/courses/).

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Список курсов располагается на нескольких страницах, так что пройдемся по всем им и поскрейпим название курса и ссылку на страницу с описанием.

# %%
MAX_NUM_PAGES = 10
year = 2020
OK_RESPONSE_STATUS = 200
course_names = []
course_links = []

for page_num in range(MAX_NUM_PAGES):
    url = f'https://www.hse.ru/ba/ami/courses/page{page_num}.html?year={year}'
    try:
        response = requests.get(url, timeout=20)
    except:
        break
    if response.status_code != OK_RESPONSE_STATUS:
        break
        
    soup = BeautifulSoup(response.content, 'html.parser')
    courses = soup.find_all('a', 'link link_dark')
    
    if not courses:
        break
        
    page_course_names = [course.text.strip() for course in courses] 
    page_course_links = [course['href'] for course in courses]
    
    assert(len(page_course_names) == len(page_course_links))
    
    course_names += page_course_names
    course_links += page_course_links

# %% [markdown]
# Создадим DataFrame из двух столбцов: название предмета и ссылка на его страничку.

# %%
df = pd.DataFrame(
    {
        'name': course_names,
        'link': course_links
    }
)

# %%
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = None

# %%
df.head(20)
# Out:
#                                                  name  \
# 0                                              DevOps
# 1                     Автоматическая обработка текста
# 2            Академическое письмо на английском языке
# 3                                             Алгебра
# 4                          Алгебра (углубленный курс)
# 5                        Алгоритмы и структуры данных
# 6                      Алгоритмы и структуры данных 2
# 7   Алгоритмы и структуры данных 2 (углубленный курс)
# 8     Алгоритмы и структуры данных (углубленный курс)
# 9                             Анализ данных в бизнесе
# 10             Analysis and Visualization of Networks
# 11                  Анализ неструктурированных данных
# 12                                    Английский язык
# 13      Архитектура компьютера и операционные системы
# 14             Байесовские методы в машинном обучении
# 15                     Безопасность жизнедеятельности
# 16                     Безопасность жизнедеятельности
# 17                   Безопасность компьютерных систем
# 18                   Безопасность компьютерных систем
# 19                      Introduction to Deep Learning
#
#                                                 link
# 0   https://www.hse.ru/ba/ami/courses/375265864.html
# 1   https://www.hse.ru/ba/ami/courses/339553234.html
# 2   https://www.hse.ru/ba/ami/courses/339581328.html
# 3   https://www.hse.ru/ba/ami/courses/394774683.html
# 4   https://www.hse.ru/ba/ami/courses/394799196.html
# 5   https://www.hse.ru/ba/ami/courses/394764539.html
# 6   https://www.hse.ru/ba/ami/courses/375294760.html
# 7   https://www.hse.ru/ba/ami/courses/375294728.html
# 8   https://www.hse.ru/ba/ami/courses/394796012.html
# 9   https://www.hse.ru/ba/ami/courses/375283606.html
# 10  https://www.hse.ru/ba/ami/courses/375265940.html
# 11  https://www.hse.ru/ba/ami/courses/375277664.html
# 12  https://www.hse.ru/ba/ami/courses/339565980.html
# 13  https://www.hse.ru/ba/ami/courses/454431540.html
# 14  https://www.hse.ru/ba/ami/courses/339569485.html
# 15  https://www.hse.ru/ba/ami/courses/394772898.html
# 16  https://www.hse.ru/ba/ami/courses/480301823.html
# 17  https://www.hse.ru/ba/ami/courses/339562255.html
# 18  https://www.hse.ru/ba/ami/courses/339562259.html
# 19  https://www.hse.ru/ba/ami/courses/375295187.html

# %%
df.shape
# Out:
# (136, 2)

# %% [markdown]
# Видим, что некоторые курсы дублируются, при чем содержание страниц одинаково (по крайней мере нужное нам), так что удалим повторения.

# %%
df = df.drop_duplicates(subset='name')
df = df.set_index('name')

# %%
df.head(20)
# Out:
#                                                                                                link
# name
# DevOps                                             https://www.hse.ru/ba/ami/courses/375265864.html
# Автоматическая обработка текста                    https://www.hse.ru/ba/ami/courses/339553234.html
# Академическое письмо на английском языке           https://www.hse.ru/ba/ami/courses/339581328.html
# Алгебра                                            https://www.hse.ru/ba/ami/courses/394774683.html
# Алгебра (углубленный курс)                         https://www.hse.ru/ba/ami/courses/394799196.html
# Алгоритмы и структуры данных                       https://www.hse.ru/ba/ami/courses/394764539.html
# Алгоритмы и структуры данных 2                     https://www.hse.ru/ba/ami/courses/375294760.html
# Алгоритмы и структуры данных 2 (углубленный курс)  https://www.hse.ru/ba/ami/courses/375294728.html
# Алгоритмы и структуры данных (углубленный курс)    https://www.hse.ru/ba/ami/courses/394796012.html
# Анализ данных в бизнесе                            https://www.hse.ru/ba/ami/courses/375283606.html
# Analysis and Visualization of Networks             https://www.hse.ru/ba/ami/courses/375265940.html
# Анализ неструктурированных данных                  https://www.hse.ru/ba/ami/courses/375277664.html
# Английский язык                                    https://www.hse.ru/ba/ami/courses/339565980.html
# Архитектура компьютера и операционные системы      https://www.hse.ru/ba/ami/courses/454431540.html
# Байесовские методы в машинном обучении             https://www.hse.ru/ba/ami/courses/339569485.html
# Безопасность жизнедеятельности                     https://www.hse.ru/ba/ami/courses/394772898.html
# Безопасность компьютерных систем                   https://www.hse.ru/ba/ami/courses/339562255.html
# Introduction to Deep Learning                      https://www.hse.ru/ba/ami/courses/375295187.html
# Introduction to Differential Geometry              https://www.hse.ru/ba/ami/courses/375284113.html
# Внутренний экзамен по английскому языку (1 курс)   https://www.hse.ru/ba/ami/courses/394762315.html

# %%
df.shape
# Out:
# (105, 1)

# %% [markdown]
# Для каждого курса на его страничке найдем информацию о формуле оценки и запишем ее в новый столбец. Также учтем, что в ПУДе некоторых курсов, к сожалению, отсутствуют формулы оценки. Выкинем такие курсы из нашего датафрейма.

# %%
row_soups = []
for row in df.iloc:
    try:
        row_response = requests.get(row.link, timeout=20)
    except:
        break
    if response.status_code != OK_RESPONSE_STATUS:
        break
        
    row_soups.append(BeautifulSoup(row_response.content, 'html.parser'))

# %%
formulas = []
for row_soup in row_soups:
    pud_sections = row_soup.find_all('div', 'pud__section')
    assessment_section = None
    for section in pud_sections:
        img = section.find('img', alt=True)
        if img and img['alt'] in ['Промежуточная аттестация', 'Interim Assessment']:
            assessment_section = section
            break
    if not assessment_section:
        formulas.append(None)
        continue
    formula = assessment_section.find_all('div', 'grey')[-1].text.strip()
    formulas.append(formula)

# %%
df['raw_formula'] = formulas
df = df.dropna()

# %%
df.head(10)
# Out:
#                                                                                                link  \
# name
# DevOps                                             https://www.hse.ru/ba/ami/courses/375265864.html
# Автоматическая обработка текста                    https://www.hse.ru/ba/ami/courses/339553234.html
# Академическое письмо на английском языке           https://www.hse.ru/ba/ami/courses/339581328.html
# Алгебра                                            https://www.hse.ru/ba/ami/courses/394774683.html
# Алгебра (углубленный курс)                         https://www.hse.ru/ba/ami/courses/394799196.html
# Алгоритмы и структуры данных                       https://www.hse.ru/ba/ami/courses/394764539.html
# Алгоритмы и структуры данных 2                     https://www.hse.ru/ba/ami/courses/375294760.html
# Алгоритмы и структуры данных 2 (углубленный курс)  https://www.hse.ru/ba/ami/courses/375294728.html
# Алгоритмы и структуры данных (углубленный курс)    https://www.hse.ru/ba/ami/courses/394796012.html
# Анализ данных в бизнесе                            https://www.hse.ru/ba/ami/courses/375283606.html
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           raw_formula
# name
# DevOps                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0.33 * HW1 + 0.33 * HW2 + 0.34 * HW3
# Автоматическая обработка текста                    Пром1 = Округление(0.3 ДЗ1 + 0.3 ДЗ2 + 0.4 Проект1) <br />Пром2 = Округление(0.3 ДЗ3 + 0.3 ДЗ4 + 0.4 Проект2). <br />O<sub>вопросы</sub>=0,5 или 0 <br />Автомат: при 1/2 Округление (Пром1+Пром2) >= 8 автоматически выставляется оценка за Экзамен = 1/2 Округление (Пром1+Пром2).<br />\nИтоговая оценка по данной учебной дисциплине (округление арифметическое):<br />\nO<sub>итоговая</sub> = Минимум(0,3·Пром<sub>1</sub> + 0,3·Пром<sub>2</sub>+0,4·O<sub>экзамен</sub>+O<sub>ответы на вопросы</sub>, 10)
# Академическое письмо на английском языке                                                                                                                                                                                                                                                                                                                                                                                                                                0.4 * Literature Review/Introduction + 0.2 * аудиторная работа + 0.4 * самостоятельная работа
# Алгебра                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.3 * Еженедельные домашние задания + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгебра (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                           0.15 * Домашнее задание 1 + 0.15 * Домашнее задание 2 + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгоритмы и структуры данных                                                                                                                                                                                                                                                                                                                                                                                                             0.4 * Домашнее задание (4 модуль) + 0.33 * Промежуточная аттестация (2 модуль) + 0.07 * Работа на семинаре 1 + 0.2 * Экзамен
# Алгоритмы и структуры данных 2                                                                                                                                                                                                                                                                                                                                                                                                                                           0.15 * Домашнее задание + 0.15 * Домашнее задание + 0.3 * Работа на семинаре + 0.4 * Экзамен
# Алгоритмы и структуры данных 2 (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.6 * Накопленная оценка + 0.4 * Экзамен
# Алгоритмы и структуры данных (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.3 * Контесты + 0.15 * Контрольные + 0.25 * Листки + 0.3 * Экзамен
# Анализ данных в бизнесе                                                                                                                                                                                                                                                                                                                                                                                        0.1 * Контрольная работа №1 + 0.1 * Контрольная работа №2 + 0.1 * Контрольная работа №3 + 0.5 * Практический проект (Командный проект) + 0.2 * Экзамен

# %%
df.shape
# Out:
# (98, 2)

# %% [markdown]
# Некоторые описания оценивания содержат ошибки форматирования, в частности теги. Почистим это, используя регулярные выражения.

# %%
import re

# %%
def clean(s : str) -> str:
    html_tags_clean_pattern = re.compile('<[^а-я]*?>|&(\w+|#\d{1,6}|#x[\da-f]{1,6});')
    res = re.sub(html_tags_clean_pattern, '', s)
    return res.replace('\n', ' ').replace('\t', ' ')

# %%
df['formula'] = df['raw_formula'].apply(lambda s : clean(s))
df = df.drop(columns='raw_formula')

# %%
df
# Out:
#                                                                                                                                    link  \
# name
# DevOps                                                                                 https://www.hse.ru/ba/ami/courses/375265864.html
# Автоматическая обработка текста                                                        https://www.hse.ru/ba/ami/courses/339553234.html
# Академическое письмо на английском языке                                               https://www.hse.ru/ba/ami/courses/339581328.html
# Алгебра                                                                                https://www.hse.ru/ba/ami/courses/394774683.html
# Алгебра (углубленный курс)                                                             https://www.hse.ru/ba/ami/courses/394799196.html
# Алгоритмы и структуры данных                                                           https://www.hse.ru/ba/ami/courses/394764539.html
# Алгоритмы и структуры данных 2                                                         https://www.hse.ru/ba/ami/courses/375294760.html
# Алгоритмы и структуры данных 2 (углубленный курс)                                      https://www.hse.ru/ba/ami/courses/375294728.html
# Алгоритмы и структуры данных (углубленный курс)                                        https://www.hse.ru/ba/ami/courses/394796012.html
# Анализ данных в бизнесе                                                                https://www.hse.ru/ba/ami/courses/375283606.html
# Analysis and Visualization of Networks                                                 https://www.hse.ru/ba/ami/courses/375265940.html
# Анализ неструктурированных данных                                                      https://www.hse.ru/ba/ami/courses/375277664.html
# Английский язык                                                                        https://www.hse.ru/ba/ami/courses/339565980.html
# Архитектура компьютера и операционные системы                                          https://www.hse.ru/ba/ami/courses/454431540.html
# Байесовские методы в машинном обучении                                                 https://www.hse.ru/ba/ami/courses/339569485.html
# Безопасность жизнедеятельности                                                         https://www.hse.ru/ba/ami/courses/394772898.html
# Безопасность компьютерных систем                                                       https://www.hse.ru/ba/ami/courses/339562255.html
# Introduction to Deep Learning                                                          https://www.hse.ru/ba/ami/courses/375295187.html
# Introduction to Differential Geometry                                                  https://www.hse.ru/ba/ami/courses/375284113.html
# Внутренний экзамен по английскому языку (1 курс)                                       https://www.hse.ru/ba/ami/courses/394762315.html
# Time Series and Stochastic Processes                                                   https://www.hse.ru/ba/ami/courses/375299810.html
# Высокопроизводительные вычисления                                                      https://www.hse.ru/ba/ami/courses/339557918.html
# Генеративные модели в машинном обучении                                                https://www.hse.ru/ba/ami/courses/339563270.html
# Глубинное обучение                                                                     https://www.hse.ru/ba/ami/courses/375287990.html
# Глубинное обучение в обработке звука                                                   https://www.hse.ru/ba/ami/courses/375297259.html
# Дискретная математика                                                                  https://www.hse.ru/ba/ami/courses/394802124.html
# Дискретная математика 2                                                                https://www.hse.ru/ba/ami/courses/375297932.html
# Дискретная математика 2 (углубленный курс)                                             https://www.hse.ru/ba/ami/courses/375282919.html
# Дискретная математика (углубленный курс)                                               https://www.hse.ru/ba/ami/courses/394765204.html
# Дискретная оптимизация                                                                 https://www.hse.ru/ba/ami/courses/339555764.html
# Дифференциальные уравнения                                                             https://www.hse.ru/ba/ami/courses/339550131.html
# Дополнительные главы прикладной статистики                                             https://www.hse.ru/ba/ami/courses/375279464.html
# Individual and Social Choice                                                           https://www.hse.ru/ba/ami/courses/375279157.html
# Operations Research and Game Theory                                                    https://www.hse.ru/ba/ami/courses/339563025.html
# Combinatorics, Graphs and Boolean Logic                                                https://www.hse.ru/ba/ami/courses/339553870.html
# Комбинаторные конструкции в теоретической информатике                                  https://www.hse.ru/ba/ami/courses/339558034.html
# Компьютерное зрение                                                                    https://www.hse.ru/ba/ami/courses/375288386.html
# Компьютерные сети                                                                      https://www.hse.ru/ba/ami/courses/375278634.html
# Conflict and Cooperation                                                               https://www.hse.ru/ba/ami/courses/375275370.html
# Cooperative Games                                                                      https://www.hse.ru/ba/ami/courses/375295757.html
# Линейная алгебра и геометрия                                                           https://www.hse.ru/ba/ami/courses/394769914.html
# Линейная алгебра и геометрия (углубленный курс)                                        https://www.hse.ru/ba/ami/courses/394793491.html
# Математический анализ                                                                  https://www.hse.ru/ba/ami/courses/394764788.html
# Математический анализ 2                                                                https://www.hse.ru/ba/ami/courses/375288220.html
# Математический анализ 2 (углубленный курс)                                             https://www.hse.ru/ba/ami/courses/375293597.html
# Математический анализ (углубленный курс)                                               https://www.hse.ru/ba/ami/courses/394760275.html
# Математическое моделирование                                                           https://www.hse.ru/ba/ami/courses/375278167.html
# Матричные вычисления                                                                   https://www.hse.ru/ba/ami/courses/375291801.html
# Машинное обучение 1                                                                    https://www.hse.ru/ba/ami/courses/339555332.html
# Машинное обучение 2                                                                    https://www.hse.ru/ba/ami/courses/339563174.html
# Машинное обучение для больших данных                                                   https://www.hse.ru/ba/ami/courses/375302485.html
# Методы и системы обработки больших данных                                              https://www.hse.ru/ba/ami/courses/375291020.html
# Методы оптимизации в машинном обучении                                                 https://www.hse.ru/ba/ami/courses/375268776.html
# Методы сжатия и передачи медиаданных                                                   https://www.hse.ru/ba/ami/courses/375266114.html
# A Theorist's Toolkit                                                                   https://www.hse.ru/ba/ami/courses/339550637.html
# Моделирование временных рядов                                                          https://www.hse.ru/ba/ami/courses/375271228.html
# Научно-исследовательский семинар "Анализ данных и искусственный интеллект 2"           https://www.hse.ru/ba/ami/courses/375277423.html
# Научно-исследовательский семинар "Инструменты промышленной разработки"                 https://www.hse.ru/ba/ami/courses/375281675.html
# Research Seminar "Mathematical and Computational Engineering in Science and Business"  https://www.hse.ru/ba/ami/courses/375295913.html
# Научно-исследовательский семинар "Машинное обучение и приложения"                      https://www.hse.ru/ba/ami/courses/339567979.html
# Научно-исследовательский семинар "Машинное обучение и приложения 2"                    https://www.hse.ru/ba/ami/courses/375270395.html
# Научно-исследовательский семинар "Принятие решений - прикладные задачи"                https://www.hse.ru/ba/ami/courses/339566442.html
# Научно-исследовательский семинар "Принятие решений - прикладные задачи 2"              https://www.hse.ru/ba/ami/courses/375287009.html
# Научно-исследовательский семинар "Распределенные системы 2"                            https://www.hse.ru/ba/ami/courses/375272473.html
# Научно-исследовательский семинар "Распределённые системы"                              https://www.hse.ru/ba/ami/courses/339549291.html
# Научно-исследовательский семинар "Теоретическая информатика"                           https://www.hse.ru/ba/ami/courses/339566215.html
# Научно-исследовательский семинар "Теоретическая информатика 2"                         https://www.hse.ru/ba/ami/courses/375279641.html
# Независимый экзамен по английскому языку                                               https://www.hse.ru/ba/ami/courses/375267860.html
# Облачные вычисления                                                                    https://www.hse.ru/ba/ami/courses/375298444.html
# Обучение с подкреплением                                                               https://www.hse.ru/ba/ami/courses/339562969.html
# Основные методы анализа данных                                                         https://www.hse.ru/ba/ami/courses/339564673.html
# Основы и методология программирования                                                  https://www.hse.ru/ba/ami/courses/394772650.html
# Основы и методология программирования (углубленный курс)                               https://www.hse.ru/ba/ami/courses/394801657.html
# Основы матричных вычислений                                                            https://www.hse.ru/ba/ami/courses/375266643.html
# Право                                                                                  https://www.hse.ru/ba/ami/courses/394768124.html
# Прикладная статистика в машинном обучении                                              https://www.hse.ru/ba/ami/courses/339551951.html
# Applied Graph Theory                                                                   https://www.hse.ru/ba/ami/courses/339558857.html
# Принятие решений в условиях риска и неопределённости                                   https://www.hse.ru/ba/ami/courses/375299774.html
# Промышленное программирование на языке Java                                            https://www.hse.ru/ba/ami/courses/375276929.html
# Распределенные системы                                                                 https://www.hse.ru/ba/ami/courses/375293520.html
# Сбор и обработка данных с помощью краудсорсинга                                        https://www.hse.ru/ba/ami/courses/375288663.html
# Semantic Technologies                                                                  https://www.hse.ru/ba/ami/courses/339555772.html
# Символьные вычисления                                                                  https://www.hse.ru/ba/ami/courses/375280135.html
# Systems Analysis                                                                       https://www.hse.ru/ba/ami/courses/375292720.html
# How to Win a Data Science Competition: Learn from Top Kagglers                         https://www.hse.ru/ba/ami/courses/375286436.html
# Теория баз данных                                                                      https://www.hse.ru/ba/ami/courses/339556374.html
# Теория вероятностей и математическая статистика                                        https://www.hse.ru/ba/ami/courses/375287950.html
# Choice and Decision Theory                                                             https://www.hse.ru/ba/ami/courses/339555682.html
# Theory of Computation                                                                  https://www.hse.ru/ba/ami/courses/339557398.html
# Теория и практика многопоточной синхронизации                                          https://www.hse.ru/ba/ami/courses/375301715.html
# Теория отказоустойчивых распределенных систем                                          https://www.hse.ru/ba/ami/courses/339559772.html
# Statistical Learning Theory                                                            https://www.hse.ru/ba/ami/courses/375266752.html
# Физическая культура                                                                    https://www.hse.ru/ba/ami/courses/339569044.html
# Философия науки                                                                        https://www.hse.ru/ba/ami/courses/375266992.html
# Функциональное программирование                                                        https://www.hse.ru/ba/ami/courses/339549313.html
# Численные методы                                                                       https://www.hse.ru/ba/ami/courses/339562855.html
# Экономика                                                                              https://www.hse.ru/ba/ami/courses/394767308.html
# Язык SQL                                                                               https://www.hse.ru/ba/ami/courses/375266084.html
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 formula
# name
# DevOps                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.33 * HW1 + 0.33 * HW2 + 0.34 * HW3
# Автоматическая обработка текста                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Пром1 = Округление(0.3 ДЗ1 + 0.3 ДЗ2 + 0.4 Проект1) Пром2 = Округление(0.3 ДЗ3 + 0.3 ДЗ4 + 0.4 Проект2). Oвопросы=0,5 или 0 Автомат: при 1/2 Округление (Пром1+Пром2) >= 8 автоматически выставляется оценка за Экзамен = 1/2 Округление (Пром1+Пром2). Итоговая оценка по данной учебной дисциплине (округление арифметическое): Oитоговая = Минимум(0,3·Пром1 + 0,3·Пром2+0,4·Oэкзамен+Oответы на вопросы, 10)
# Академическое письмо на английском языке                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.4 * Literature Review/Introduction + 0.2 * аудиторная работа + 0.4 * самостоятельная работа
# Алгебра                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.3 * Еженедельные домашние задания + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгебра (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.15 * Домашнее задание 1 + 0.15 * Домашнее задание 2 + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгоритмы и структуры данных                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.4 * Домашнее задание (4 модуль) + 0.33 * Промежуточная аттестация (2 модуль) + 0.07 * Работа на семинаре 1 + 0.2 * Экзамен
# Алгоритмы и структуры данных 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.15 * Домашнее задание + 0.15 * Домашнее задание + 0.3 * Работа на семинаре + 0.4 * Экзамен
# Алгоритмы и структуры данных 2 (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.6 * Накопленная оценка + 0.4 * Экзамен
# Алгоритмы и структуры данных (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.3 * Контесты + 0.15 * Контрольные + 0.25 * Листки + 0.3 * Экзамен
# Анализ данных в бизнесе                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.1 * Контрольная работа №1 + 0.1 * Контрольная работа №2 + 0.1 * Контрольная работа №3 + 0.5 * Практический проект (Командный проект) + 0.2 * Экзамен
# Analysis and Visualization of Networks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.15 * Home assignment 1 + 0.15 * Home assignment 2 + 0.15 * Home assignment 3 + 0.15 * In-class assignments + 0.4 * Individual project
# Анализ неструктурированных данных                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.075 * Домашнее задание (ДЗ 3) + 0.075 * Домашнее задание (ДЗ1) + 0.075 * Домашнее задание (ДЗ2) + 0.075 * Домашнее задание (ДЗ4) + 0.12 * Компьютерный тест (Квизы) + 0.09 * Проект 1 (Домашнее задание) + 0.09 * Проект 2 (Домашнее задание) + 0.4 * Устный экзамен
# Английский язык                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.1 * Аттестационная работа + 0.2 * Письменные элементы контроля + 0.1 * Самостоятельная работа + 0.2 * Устные элементы контроля + 0.4 * Устный и письменный экзамен
# Архитектура компьютера и операционные системы                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.6 * Накопленная оценка (контрольные, домашние работы, работа на семинарах) + 0.4 * Экзамен
# Байесовские методы в машинном обучении                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.229 * Домашнее задание (лабораторные) + 0.3 * Домашнее задание (практические) + 0.171 * Домашнее задание (теоретические) + 0.3 * Устный экзамен
# Безопасность жизнедеятельности                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.4 * Домашнее задание + 0.6 * Экзамен
# Безопасность компьютерных систем                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.7 * Домашние задания + 0.3 * Экзамен
# Introduction to Deep Learning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.4 * Homeworks + 0.3 * Online course + 0.3 * Tests
# Introduction to Differential Geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.5 * Current assessment + 0.5 * Exam
# Внутренний экзамен по английскому языку (1 курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.25 * Listening + 0.25 * Reading + 0.25 * Speaking + 0.25 * Writing
# Time Series and Stochastic Processes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.4 * EX (final exam) + 0.2 * HW (Homework) + 0.3 * MEX (mid-term exam) + 0.1 * SG (Participation in the statistical game)
# Высокопроизводительные вычисления                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.125 * Лабораторная работа 1 + 0.125 * Лабораторная работа 2 + 0.125 * Лабораторная работа 3 + 0.125 * Лабораторная работа 4 + 0.5 * Экзамен
# Генеративные модели в машинном обучении                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.16 * Домашнее задание 1 + 0.16 * Домашнее задание 2 + 0.16 * Домашнее задание 3  + 0.16 * Домашнее задание 4 + 0.16 * Проект + 0.2 * Экзамен
# Глубинное обучение                                                                                                   О_ДЗ1, О_ДЗ2, О_ДЗ3: Итоговые оценки за домашние задания, шкала от 0 до 10.   О_накопл: Накопленная оценка выставляется по итогам работы в семестре по следующей нелинейной формуле, шкала от 0 до 10.   О_накопл := округление( О_ДЗ1 * w_ДЗ1 + О_ДЗ2 * w_ДЗ2 + О_ДЗ3 * w_ДЗ3), где веса w_ДЗ1, w_ДЗ2, w_ДЗ3 вычисляются при помощи взвешенной функции softmin.   w_ДЗ1 := s_ДЗ1 / (s_ДЗ1 + s_ДЗ2 + s_ДЗ3) w_ДЗ2 := s_ДЗ2 / (s_ДЗ1 + s_ДЗ2 + s_ДЗ3) w_ДЗ3 := s_ДЗ3 / (s_ДЗ1 + s_ДЗ2 + s_ДЗ3)   s_ДЗ1 := exp( -О_ДЗ1 / T)  s_ДЗ2 := exp( -О_ДЗ2 / T)  s_ДЗ3 := exp( -О_ДЗ3 / T)   Значения параметров: T:= 20   О_Э: оценка за экзамен выставляется в шкале от 0 до 10. По взаимному согласию студента и преподавателя оценка за экзамен может быть выставлена равной накопленной оценке.  Итоговая оценка вычисляется по формуле О_итог := округление(0.7 * О_накопл + 0.3 * О_Э)
# Глубинное обучение в обработке звука                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.7 * Домашние задания + 0.15 * Проект + 0.15 * Экзамен
# Дискретная математика                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.083 * Домашнее задание 1 + 0.083 * Домашнее задание 2 + 0.084 * Домашнее задание 3 + 0.3 * Итоговый экзамен + 0.15 * Коллоквиум 1 + 0.15 * Коллоквиум 2 + 0.15 * Промежуточный экзамен
# Дискретная математика 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.3 * Домашнее задание + 0.35 * Коллоквиум + 0.35 * Письменный экзамен
# Дискретная математика 2 (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.2 * Домашнее задание + 0.4 * Коллоквиум + 0.4 * Письменный экзамен
# Дискретная математика (углубленный курс)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.083 * Домашнее задание 1 + 0.083 * Домашнее задание 2 + 0.084 * Домашнее задание 3 + 0.3 * Итоговый экзамен + 0.15 * Коллоквиум 1 + 0.15 * Коллоквиум 2 + 0.15 * Промежуточный экзамен
# Дискретная оптимизация                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.67 * Накопленая оценка + 0.33 * Экзамен
# Дифференциальные уравнения                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.3 * Домашние задания + 0.3 * Контрольная работа + 0.4 * Экзамен
# Дополнительные главы прикладной статистики                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.2 * Домашнее задание 1 + 0.2 * Домашнее задание 2 + 0.2 * Домашнее задание 3 + 0.2 * Домашнее задание 4 + 0.1 * Коллоквиум + 0.1 * Письменный экзамен
# Individual and Social Choice                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.3 *  midterm + 0.1 * attendance + 0.4 * final exam + 0.2 * homework
# ...
# Символьные вычисления                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Итоговая оценка = Округление (0.15*ДЗ1+0.15*ДЗ2+0.3*КР+0.4*ЭК),   где ДЗ1 – оценка за домашнее задание № 1, ДЗ2 – оценка за домашнее задание № 2, КР – оценка за контрольную работу и ЭК – оценка за устный экзамен.   Блокирующих элементов контроля в курсе нет. Автоматы не выставляются.
# Systems Analysis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.5 * Oexam + 0.1 * Oproject1 + 0.15 * Oproject2 + 0.25 * Otest
# How to Win a Data Science Competition: Learn from Top Kagglers                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.7 * Competition + 0.3 * Online course
# Теория баз данных                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Дисциплина предполагает следующую структуру итоговой оценки: Отекущий = 0,15·Од/з1 + 0,15·Од/з2 + 0,2·Од/з3 + 0,2·Од/з4 + 0,2·Ок/р + 0,1·Оаудиторная Одисциплина = 0,3·Оэкзамен + 0,7·Отекущий Оценки по всем формам текущего и завершающего контроля выставляются по десятибалльной шкале. Первая и вторая пересдачи проводятся в форме, максимально приближенной к устному экзамену по дисциплине.
# Теория вероятностей и математическая статистика                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Накопленная оценка 2-го этапа рассчитывается по формуле: Накоп2=Округление(10/17*Пром1 + 7/17*[2/7*(КЛ3+КЛ4)+ 3/7*min(10,КР3+КР4)+2/7*ДЗ2]). Результирующая оценка по учебной дисциплине рассчитывается по следующей формуле: Итог=Округление(0.85*Накоп2 + 0.15*Экз2) - итоговая оценка по дисциплине
# Choice and Decision Theory                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.6 * final exam + 0.2 * homework  + 0.2 * mid-term exam
# Theory of Computation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.35 * Colloquium + 0.3 * Exam + 0.35 * Homework
# Теория и практика многопоточной синхронизации                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0.5 * Домашние задания + 0.5 * Домашние задания
# Теория отказоустойчивых распределенных систем                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.7 * Домашние задания + 0.3 * Экзамен
# Statistical Learning Theory                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.3 * Colloqium + 0.35 * Exam + 0.35 * Homework
# Физическая культура                                                                                                                                                                                                                                                                                                                                                                 Зачёт по предмету выставляется, если студент успешно сдал все семестровые зачёты и итоговый зачёт. Для получения семестровых зачётов необходимо, чтобы студент участвовал не менее чем в 75% занятий по направлению, а также непосредственно выполнил комплекс упражнений в рамках семестрового зачёта.  В случае, если студент по уважительной причине пропустил более 25% занятий в семестре, семестровый зачёт заменяется рефератом на тему, соответствующую теме занятий. Семестровые зачёты и пропущенные без уважительной причины занятия можно пересдать по предварительной договорённости с преподавателем.
# Философия науки                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0,6 * (оценка за экзамен) + 0,4 * (сумма баллов за текущую работу, но не более 10)
# Функциональное программирование                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Итоговая оценка формируется следующим образом: 0,7*(накоп.) + 0,3*(экзамен), где (экзамен) - оценка за итоговый экзамен, а (накоп.) - накопленная оценка за семестр, определяемая следующим образом:  (накоп.) = 0,72*(прог.) + 0,28*(контр.), где (прог.) - суммарная оценка за программистские домашние задания, (сам.) - оценка за контрольную работу.
# Численные методы                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.28 * Домашнее задание + 0.42 * Контрольная работа 1 + 0.3 * Экзамен
# Экономика                                                                                                                                                                                                                                                                                                                                       Итоговая оценка по курсу складывается из оценок за работу на семинарах, за выполненное домашнее задание, за тесты, выполненные в онлайн-курсе «Экономика для неэкономистов», за 2 контрольные работы - по микро и макроэкономике, за  контрольную по курсу «Управление личными финансами»: Результирующая оценка по дисциплине формируется с учетом оценок по всем формам контроля.  Орез=0,225 х К1 + 0,225 х К2, + 0,075 х д/з + 0,075 х Тесты в онлайн + 0,25 х К3 + 0,15 х Работа на семинарах.  Экзамен не предусмотрен, итоговая оценка формируется как накопленная с учетом всех элементов контроля.  Блокирующие элементы контроля отсутствуют.
# Язык SQL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.05 * Домашнее задание 1 + 0.1 * Домашнее задание 10 + 0.03 * Домашнее задание 11 + 0.03 * Домашнее задание 2 + 0.05 * Домашнее задание 3 + 0.05 * Домашнее задание 4 + 0.12 * Домашнее задание 5 + 0.03 * Домашнее задание 6 + 0.03 * Домашнее задание 7 + 0.05 * Домашнее задание 8 + 0.06 * Домашнее задание 9 + 0.4 * Экзамен

# %% [markdown]
# Хотим теперь отпарсить формулы так, чтобы можно было вычислять значения оценки по списку значений ее компонент. Для начала заметим, что подавляющее большинство формул записано в довольно хорошем формате, то есть как
#
# $$weight_1 * O_1 +  weight_2 * O_2 + \dots$$
#
# Поработаем с ними, сложные формулы с длинными описаниями различных условий пока откинем. Сделаем это достаточно наивно: оставим только курсы с длиной формулы не более 200 символов.

# %%
from copy import deepcopy

# %%
df_short = deepcopy(df[df.formula.map(len) <= 200])
df_short.shape
# Out:
# (74, 2)

# %%
df_short.head(10)
# Out:
#                                                                                                link  \
# name
# DevOps                                             https://www.hse.ru/ba/ami/courses/375265864.html
# Академическое письмо на английском языке           https://www.hse.ru/ba/ami/courses/339581328.html
# Алгебра                                            https://www.hse.ru/ba/ami/courses/394774683.html
# Алгебра (углубленный курс)                         https://www.hse.ru/ba/ami/courses/394799196.html
# Алгоритмы и структуры данных                       https://www.hse.ru/ba/ami/courses/394764539.html
# Алгоритмы и структуры данных 2                     https://www.hse.ru/ba/ami/courses/375294760.html
# Алгоритмы и структуры данных 2 (углубленный курс)  https://www.hse.ru/ba/ami/courses/375294728.html
# Алгоритмы и структуры данных (углубленный курс)    https://www.hse.ru/ba/ami/courses/394796012.html
# Анализ данных в бизнесе                            https://www.hse.ru/ba/ami/courses/375283606.html
# Analysis and Visualization of Networks             https://www.hse.ru/ba/ami/courses/375265940.html
#
#                                                                                                                                                                                                   formula
# name
# DevOps                                                                                                                                                               0.33 * HW1 + 0.33 * HW2 + 0.34 * HW3
# Академическое письмо на английском языке                                                                    0.4 * Literature Review/Introduction + 0.2 * аудиторная работа + 0.4 * самостоятельная работа
# Алгебра                                                                                                                    0.3 * Еженедельные домашние задания + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгебра (углубленный курс)                                                                               0.15 * Домашнее задание 1 + 0.15 * Домашнее задание 2 + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгоритмы и структуры данных                                                 0.4 * Домашнее задание (4 модуль) + 0.33 * Промежуточная аттестация (2 модуль) + 0.07 * Работа на семинаре 1 + 0.2 * Экзамен
# Алгоритмы и структуры данных 2                                                                               0.15 * Домашнее задание + 0.15 * Домашнее задание + 0.3 * Работа на семинаре + 0.4 * Экзамен
# Алгоритмы и структуры данных 2 (углубленный курс)                                                                                                                0.6 * Накопленная оценка + 0.4 * Экзамен
# Алгоритмы и структуры данных (углубленный курс)                                                                                       0.3 * Контесты + 0.15 * Контрольные + 0.25 * Листки + 0.3 * Экзамен
# Анализ данных в бизнесе                            0.1 * Контрольная работа №1 + 0.1 * Контрольная работа №2 + 0.1 * Контрольная работа №3 + 0.5 * Практический проект (Командный проект) + 0.2 * Экзамен
# Analysis and Visualization of Networks                            0.15 * Home assignment 1 + 0.15 * Home assignment 2 + 0.15 * Home assignment 3 + 0.15 * In-class assignments + 0.4 * Individual project

# %% [markdown]
# Для хранения формулы напишем класс, который будем содержать в себе два поля: список весов и список названий элементов контроля.

# %%
from __future__ import annotations
import numpy as np
from typing import Tuple, Type


class Grade:

    def __init__(self, weights: Tuple[float], names: Tuple[str]) -> None:
        assert(len(weights) == len(names))
        self.weights = np.array(weights)
        self.names = np.array(names)

    def __call__(self, values: Tuple[float]) -> float:
        assert(len(self.weights) == len(values))
        return sum(self.weights * np.array(values))

    def __repr__(self) -> str:
        return 'Grade(' + 'weights: ' + str(self.weights) + ', names: ' + str(self.names) + ')'

    @staticmethod
    def from_string(formula: str) -> Grade:
        # splitting into terms by '+'
        terms = tuple(
            map(str.strip,
                formula.split('+')
                )
        )
        # splitting each terms into weight and mark by '*'
        weights_names = tuple(
            map(lambda s: s.split('*'),
                terms)
        )
        # tranforming data into two tuples : weights of marks and names of marks
        weights, names = tuple(
            zip(*weights_names)
        )
        # unifying numbers format
        weights = tuple(
            map(
                float,
                map(
                    lambda s: s.replace(',', '.'),
                    map(str.strip,
                        weights
                        )
                )
            )
        )
        # stripping marks' names
        names = tuple(
            map(
                str.strip,
                names
            )
        )
        return Grade(weights, names)

# %% [markdown]
# (Манипуляции с записью класса в файл и его импортированием связаны с тем, что в дальнейшем мы будем использовать этот класс в веб-приложении и чтобы данные сериализовались, а потом подгружались корректно необходимо, чтобы класс сразу лежал в файле grade.py)

# %% [markdown]
# Создадим новый столбец с объектом класса Grade.

# %%
grades = []
for row in df_short.iloc:
    grades.append(Grade.from_string(row.formula))

# %%
df_short['grade'] = grades

# %%
df_short.tail(10)
# Out:
#                                                                                                             link  \
# name
# Semantic Technologies                                           https://www.hse.ru/ba/ami/courses/339555772.html
# Systems Analysis                                                https://www.hse.ru/ba/ami/courses/375292720.html
# How to Win a Data Science Competition: Learn from Top Kagglers  https://www.hse.ru/ba/ami/courses/375286436.html
# Choice and Decision Theory                                      https://www.hse.ru/ba/ami/courses/339555682.html
# Theory of Computation                                           https://www.hse.ru/ba/ami/courses/339557398.html
# Теория и практика многопоточной синхронизации                   https://www.hse.ru/ba/ami/courses/375301715.html
# Теория отказоустойчивых распределенных систем                   https://www.hse.ru/ba/ami/courses/339559772.html
# Statistical Learning Theory                                     https://www.hse.ru/ba/ami/courses/375266752.html
# Философия науки                                                 https://www.hse.ru/ba/ami/courses/375266992.html
# Численные методы                                                https://www.hse.ru/ba/ami/courses/339562855.html
#
#                                                                                                                                            formula  \
# name
# Semantic Technologies                                                                                 0.4 * Exam + 0.6 * In-class tasks/ homeworks
# Systems Analysis                                                                   0.5 * Oexam + 0.1 * Oproject1 + 0.15 * Oproject2 + 0.25 * Otest
# How to Win a Data Science Competition: Learn from Top Kagglers                                             0.7 * Competition + 0.3 * Online course
# Choice and Decision Theory                                                                0.6 * final exam + 0.2 * homework  + 0.2 * mid-term exam
# Theory of Computation                                                                             0.35 * Colloquium + 0.3 * Exam + 0.35 * Homework
# Теория и практика многопоточной синхронизации                                                      0.5 * Домашние задания + 0.5 * Домашние задания
# Теория отказоустойчивых распределенных систем                                                               0.7 * Домашние задания + 0.3 * Экзамен
# Statistical Learning Theory                                                                        0.3 * Colloqium + 0.35 * Exam + 0.35 * Homework
# Философия науки                                                 0,6 * (оценка за экзамен) + 0,4 * (сумма баллов за текущую работу, но не более 10)
# Численные методы                                                             0.28 * Домашнее задание + 0.42 * Контрольная работа 1 + 0.3 * Экзамен
#
#                                                                                                                                                                        grade
# name
# Semantic Technologies                                                                                 Grade(weights: [0.4 0.6], names: ['Exam' 'In-class tasks/ homeworks'])
# Systems Analysis                                                                     Grade(weights: [0.5  0.1  0.15 0.25], names: ['Oexam' 'Oproject1' 'Oproject2' 'Otest'])
# How to Win a Data Science Competition: Learn from Top Kagglers                                             Grade(weights: [0.7 0.3], names: ['Competition' 'Online course'])
# Choice and Decision Theory                                                                   Grade(weights: [0.6 0.2 0.2], names: ['final exam' 'homework' 'mid-term exam'])
# Theory of Computation                                                                              Grade(weights: [0.35 0.3  0.35], names: ['Colloquium' 'Exam' 'Homework'])
# Теория и практика многопоточной синхронизации                                                      Grade(weights: [0.5 0.5], names: ['Домашние задания' 'Домашние задания'])
# Теория отказоустойчивых распределенных систем                                                               Grade(weights: [0.7 0.3], names: ['Домашние задания' 'Экзамен'])
# Statistical Learning Theory                                                                         Grade(weights: [0.3  0.35 0.35], names: ['Colloqium' 'Exam' 'Homework'])
# Философия науки                                                 Grade(weights: [0.6 0.4], names: ['(оценка за экзамен)' '(сумма баллов за текущую работу, но не более 10)'])
# Численные методы                                                              Grade(weights: [0.28 0.42 0.3 ], names: ['Домашнее задание' 'Контрольная работа 1' 'Экзамен'])

# %% [markdown]
# Сохраним получившийся датафрейм используя модуль pickle для сериализации объектов класса Grade.

# %%
df_short.to_pickle('assessment_db.pkl')

# %% [markdown]
# Проверим, что все работает и данные выгружаются в нужном формате.

# %%
db = pd.read_pickle('assessment_db.pkl')
db.head()
# Out:
#                                                                                       link  \
# name
# DevOps                                    https://www.hse.ru/ba/ami/courses/375265864.html
# Академическое письмо на английском языке  https://www.hse.ru/ba/ami/courses/339581328.html
# Алгебра                                   https://www.hse.ru/ba/ami/courses/394774683.html
# Алгебра (углубленный курс)                https://www.hse.ru/ba/ami/courses/394799196.html
# Алгоритмы и структуры данных              https://www.hse.ru/ba/ami/courses/394764539.html
#
#                                                                                                                                                                formula  \
# name
# DevOps                                                                                                                            0.33 * HW1 + 0.33 * HW2 + 0.34 * HW3
# Академическое письмо на английском языке                                 0.4 * Literature Review/Introduction + 0.2 * аудиторная работа + 0.4 * самостоятельная работа
# Алгебра                                                                                 0.3 * Еженедельные домашние задания + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгебра (углубленный курс)                                            0.15 * Домашнее задание 1 + 0.15 * Домашнее задание 2 + 0.2 * Контрольная работа + 0.5 * Экзамен
# Алгоритмы и структуры данных              0.4 * Домашнее задание (4 модуль) + 0.33 * Промежуточная аттестация (2 модуль) + 0.07 * Работа на семинаре 1 + 0.2 * Экзамен
#
#                                                                                                                                                                                            grade
# name
# DevOps                                                                                                                              Grade(weights: [0.33 0.33 0.34], names: ['HW1' 'HW2' 'HW3'])
# Академическое письмо на английском языке                                 Grade(weights: [0.4 0.2 0.4], names: ['Literature Review/Introduction' 'аудиторная работа'\n 'самостоятельная работа'])
# Алгебра                                                                                   Grade(weights: [0.3 0.2 0.5], names: ['Еженедельные домашние задания' 'Контрольная работа' 'Экзамен'])
# Алгебра (углубленный курс)                                              Grade(weights: [0.15 0.15 0.2  0.5 ], names: ['Домашнее задание 1' 'Домашнее задание 2' 'Контрольная работа' 'Экзамен'])
# Алгоритмы и структуры данных              Grade(weights: [0.4  0.33 0.07 0.2 ], names: ['Домашнее задание (4 модуль)' 'Промежуточная аттестация (2 модуль)'\n 'Работа на семинаре 1' 'Экзамен'])

# %%
type(db.iloc[0]['grade'])
# Out:
# __main__.Grade
